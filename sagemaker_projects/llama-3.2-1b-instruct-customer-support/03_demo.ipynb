# %% [markdown]
# # Demo: Base Model vs SageMaker Fine-Tuned Model
#
# This notebook compares the **base Llama-3.2-1B-Instruct** model (run locally via MLX) against the **SageMaker fine-tuned** model on customer support ticket triage.
#
# ## Overview
# - **Base Model**: Llama-3.2-1B-Instruct (local MLX inference)
# - **Fine-Tuned Model**: SageMaker endpoint with LoRA adapters
# - **Task**: Convert customer tickets → internal bug reports with severity, owner, and investigation steps
#
# **Prerequisites:**
# - SageMaker endpoint deployed (from notebook 02)
# - Endpoint must be InService

# %% [markdown]
# ## 1. Setup and Configuration

# %%
import json
import os
import boto3
from pathlib import Path
from mlx_lm import load, generate

print("Setup complete!")

# %%
# Configuration
MODEL_NAME = "mlx-community/Llama-3.2-1B-Instruct-bf16"
REGION = "eu-west-2"

# UPDATE THESE with values from notebook 02
ENDPOINT_NAME = "ep-llama-3-2-1b-customer-support-2026-01-13-18-39-45-600"
INFERENCE_COMPONENT_NAME = "ic-llama-3-2-1b-customer-support-2026-01-13-18-39-45-600"

# Create SageMaker clients
sm_client = boto3.client("sagemaker", region_name=REGION)
sagemaker_runtime = boto3.client("sagemaker-runtime", region_name=REGION)

print(f"Base Model: {MODEL_NAME}")
print(f"SageMaker Endpoint: {ENDPOINT_NAME}")
print(f"Inference Component: {INFERENCE_COMPONENT_NAME}")

# %% [markdown]
# ## 2. Verify SageMaker Endpoint

# %%
# Verify endpoint is ready
try:
    endpoint_desc = sm_client.describe_endpoint(EndpointName=ENDPOINT_NAME)
    ic_desc = sm_client.describe_inference_component(InferenceComponentName=INFERENCE_COMPONENT_NAME)

    endpoint_status = endpoint_desc["EndpointStatus"]
    ic_status = ic_desc["InferenceComponentStatus"]

    print(f"Endpoint status: {endpoint_status}")
    print(f"Inference component status: {ic_status}")

    if endpoint_status != "InService" or ic_status != "InService":
        raise Exception(f"Resources not ready. Endpoint: {endpoint_status}, IC: {ic_status}")

    print("\n✓ SageMaker endpoint ready!")
except Exception as e:
    print(f"\n❌ Error: {e}")
    print("\nMake sure you've:")
    print("1. Completed notebook 02 (deploy)")
    print("2. Updated ENDPOINT_NAME and INFERENCE_COMPONENT_NAME above")
    raise

# %% [markdown]
# ## 3. Load Test Data

# %%
# Load test data (6 samples, 1 per category)
test_data_path = Path("tmp_cache_local_dataset/test_data_with_categories.jsonl")

eval_data = []
with open(test_data_path, "r") as f:
    for line in f:
        line = line.strip()
        if line:
            eval_data.append(json.loads(line))

print(f"Loaded {len(eval_data)} test samples")
print("\nCategories:")
for sample in eval_data:
    print(f"  - {sample['category']}")

# Preview first sample
print("\nSample entry:")
print("=" * 60)
sample = eval_data[0]
user_msg = sample["messages"][0]["content"]
print(f"USER INPUT:\n{user_msg[:300]}...")

# %% [markdown]
# ## 4. Generate Responses
#
# Run inference on all test samples using:
# - **Base model**: Local MLX inference
# - **Fine-tuned model**: SageMaker endpoint

# %%
def invoke_sagemaker_model(messages, max_tokens=500, temperature=0.1):
    """Invoke the SageMaker fine-tuned model."""
    payload = {
        "messages": messages,
        "temperature": temperature,
        "top_p": 0.9,
        "max_tokens": max_tokens,
    }

    response = sagemaker_runtime.invoke_endpoint(
        EndpointName=ENDPOINT_NAME,
        InferenceComponentName=INFERENCE_COMPONENT_NAME,
        ContentType="application/json",
        Body=json.dumps(payload),
    )

    result = json.loads(response["Body"].read().decode("utf-8"))
    return result["choices"][0]["message"]["content"].strip()


def generate_base_responses(model, tokenizer, test_data, max_tokens=500):
    """Generate responses using local MLX base model."""
    responses = []
    for i, sample in enumerate(test_data):
        user_content = sample["messages"][0]["content"]

        # Build prompt using chat template
        prompt = tokenizer.apply_chat_template(
            [{"role": "user", "content": user_content}],
            add_generation_prompt=True,
            tokenize=False,
        )

        # Generate response
        response = generate(model, tokenizer, prompt=prompt, max_tokens=max_tokens, verbose=False)
        responses.append(response)
        print(f"Generated {i + 1}/{len(test_data)}")

    return responses


print("Helper functions defined.")

# %%
# Load and run base model (local MLX)
print("=" * 60)
print("LOADING BASE MODEL (Local MLX)")
print("=" * 60)

base_model, base_tokenizer = load(MODEL_NAME)

print("\nGenerating responses with base model...")
base_responses = generate_base_responses(base_model, base_tokenizer, eval_data)

print("\nBase model generation complete!")

# %%
# Generate responses with fine-tuned model (SageMaker endpoint)
print("=" * 60)
print("GENERATING WITH FINE-TUNED MODEL (SageMaker)")
print("=" * 60)

finetuned_responses = []
for i, sample in enumerate(eval_data):
    user_content = sample["messages"][0]["content"]
    input_messages = [{"role": "user", "content": user_content}]

    response = invoke_sagemaker_model(input_messages)
    finetuned_responses.append(response)
    print(f"Generated {i + 1}/{len(eval_data)}")

print("\nFine-tuned model generation complete!")

# %% [markdown]
# ## 5. Compare Outputs
#
# Display side-by-side comparison of base model vs fine-tuned model outputs for each test sample.

# %%
from IPython.display import display, HTML
import html as html_module


def styled_comparison(idx, total, user_content, expected, finetuned, base):
    """Generate styled HTML for a single comparison (Equal Experts brand)."""
    user_esc = html_module.escape(user_content).replace("\n", "<br>")
    expected_esc = html_module.escape(expected).replace("\n", "<br>")
    finetuned_esc = html_module.escape(finetuned).replace("\n", "<br>")
    base_esc = html_module.escape(base).replace("\n", "<br>")

    # Equal Experts Brand Colors
    # Primary: EE Blue #1795D4, Secondary: Tech Blue #22567C
    # Accents: Transform Teal #269C9E, Equal Ember #F07C00
    # Neutrals: Dark Data #212526, The Cloud #F5F5F5, Byte White #FFFFFF

    return f"""
    <link href="https://fonts.googleapis.com/css2?family=Lexend:wght@300;400;500&display=swap" rel="stylesheet">
    <div style="font-family: 'Lexend', sans-serif; margin: 24px 0; overflow: hidden; box-shadow: 0 2px 8px rgba(33,37,38,0.1); border: 1px solid #E0E0E0;">
        <div style="background: #22567C; color: #FFFFFF; padding: 18px 24px; font-size: 20px; font-weight: 400;">
            Sample {idx} of {total}
        </div>

        <div style="background: #FFFFFF; border-left: 6px solid #1795D4; padding: 18px 22px;">
            <div style="font-weight: 500; color: #22567C; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
                Customer Ticket
            </div>
            <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">{user_esc}</div>
        </div>

        <div style="background: #F5F5F5; border-left: 6px solid #269C9E; padding: 18px 22px;">
            <div style="font-weight: 500; color: #269C9E; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
                Fine-Tuned Model Response (SageMaker)
            </div>
            <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">{finetuned_esc}</div>
        </div>

        <div style="background: #FFFFFF; border-left: 6px solid #212526; padding: 18px 22px;">
            <div style="font-weight: 500; color: #212526; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
                Base Model Response (Local MLX)
            </div>
            <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">{base_esc}</div>
        </div>

        <details style="background: #F5F5F5; border-left: 6px solid #F07C00; padding: 18px 22px;">
            <summary style="font-weight: 500; color: #22567C; font-size: 13px; text-transform: uppercase; letter-spacing: 1px; cursor: pointer; border-radius: 4px; padding: 4px 0;">
                Expected Response (Ground Truth) — click to expand
            </summary>
            <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; margin-top: 14px; color: #212526; line-height: 1.6;">{expected_esc}</div>
        </details>
    </div>
    """


# Display styled comparisons
for i, sample in enumerate(eval_data):
    user_content = sample["messages"][0]["content"]
    expected_output = sample["messages"][1]["content"]

    display(
        HTML(
            styled_comparison(
                i + 1, len(eval_data), user_content, expected_output, finetuned_responses[i], base_responses[i]
            )
        )
    )
# Out:
#     <link href="https://fonts.googleapis.com/css2?family=Lexend:wght@300;400;500&display=swap" rel="stylesheet">
#     <div style="font-family: 'Lexend', sans-serif; margin: 24px 0; overflow: hidden; box-shadow: 0 2px 8px rgba(33,37,38,0.1); border: 1px solid #E0E0E0;">
#         <div style="background: #22567C; color: #FFFFFF; padding: 18px 24px; font-size: 20px; font-weight: 400;">
#             Sample 1 of 6
#         </div>
#
#         <div style="background: #FFFFFF; border-left: 6px solid #1795D4; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #22567C; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Customer Ticket
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">Ticket #7823<br>Customer: rachel.thompson@meridian.com<br>Plan: Enterprise<br>Issue: URGENT - Our entire reporting suite is down. Every dashboard just shows &quot;No data available&quot;. We&#x27;re in the middle of month-end close and finance is losing it. Need this fixed NOW.</div>
#         </div>
#
#         <div style="background: #F5F5F5; border-left: 6px solid #269C9E; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #269C9E; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Fine-Tuned Model Response (SageMaker)
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">## Internal Bug Report<br><br>Severity: P1 (business-critical)<br><br>Owner: Data Services Team<br><br>Summary: Reporting suite down, causing month-end close disruption<br><br>Probable Cause: API endpoint that fetches data from external sources is returning an error, likely due to rate limiting or service unavailability.<br><br>Suggested Investigation:<br>1. Check API logs for error messages related to data fetching<br>2. Review rate limiting configuration for external services<br>3. Run `curl -X GET /reporting/slice?date=2022-01-01&amp;limit=1000` in finance team&#x27;s terminal to verify data is being fetched correctly</div>
#         </div>
#
#         <div style="background: #FFFFFF; border-left: 6px solid #212526; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #212526; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Base Model Response (Local MLX)
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">**URGENT - Reporting Suite Down**<br><br>**Customer Information:**<br><br>- Name: Rachel Thompson<br>- Email: rachel.thompson@meridian.com<br>- Plan: Enterprise<br><br>**Issue Description:**<br><br>- The entire reporting suite is currently down, causing all dashboards to display &quot;No data available&quot;.<br>- This is a critical situation, as we are in the middle of month-end close and finance is losing control.<br>- Immediate resolution is required to prevent further disruptions and ensure timely financial close.<br><br>**Request:**<br><br>We require immediate assistance to resolve this issue. The following steps will be taken:<br><br>1. **Remote Access:** Grant remote access to the affected system to facilitate troubleshooting and potential fixes.<br>2. **Diagnostic Tools:** Utilize diagnostic tools to identify the root cause of the issue and determine the necessary course of action.<br>3. **Escalation:** Escalate the issue to our technical team for further assistance and support.<br>4. **Timeline:** Provide a timeline for the resolution of the issue, including any potential downtime or disruptions.<br><br>**Next Steps:**<br><br>- The technical team will work on resolving the issue as soon as possible.<br>- A follow-up email will be sent to the customer with an update on the status of the issue.<br>- The customer will be contacted to discuss any further actions required to ensure the successful resolution of the issue.<br><br>**Contact Information:**<br><br>- Technical Support: [support@meridian.com](mailto:support@meridian.com)<br>- Customer Support: [support@meridian.com](mailto:support@meridian.com)<br><br>**Resolution Timeline:**<br><br>- Within the hour: Remote access granted and diagnostic tools utilized to identify the root cause of the issue.<br>- Within 2 hours: Escalation to technical team and timeline for resolution provided to the customer.<br>- Within 4 hours: Resolution of the issue, and a follow-up email sent to the customer with an update on the status of the issue.</div>
#         </div>
#
#         <details style="background: #F5F5F5; border-left: 6px solid #F07C00; padding: 18px 22px;">
#             <summary style="font-weight: 500; color: #22567C; font-size: 13px; text-transform: uppercase; letter-spacing: 1px; cursor: pointer; border-radius: 4px; padding: 4px 0;">
#                 Expected Response (Ground Truth) — click to expand
#             </summary>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; margin-top: 14px; color: #212526; line-height: 1.6;">## Internal Bug Report<br><br>Severity: P1 (business-critical)<br><br>Owner: Data Platform Team<br><br>Summary: Complete reporting suite outage showing &quot;No data available&quot; during month-end close<br><br>Probable Cause: Snowflake warehouse REPORTS_WH may be suspended or ETL pipeline has failed upstream, leaving all mart tables empty or inaccessible.<br><br>Suggested Investigation:<br>1. Check Snowflake warehouse status for `REPORTS_WH` - verify it&#x27;s not suspended or out of credits<br>2. Run `/scripts/etl/dag_status.sh` to identify failed DAGs in the reporting pipeline<br>3. Check #data-platform-alerts for Snowflake connection or credential errors</div>
#         </details>
#     </div>
#     <link href="https://fonts.googleapis.com/css2?family=Lexend:wght@300;400;500&display=swap" rel="stylesheet">
#     <div style="font-family: 'Lexend', sans-serif; margin: 24px 0; overflow: hidden; box-shadow: 0 2px 8px rgba(33,37,38,0.1); border: 1px solid #E0E0E0;">
#         <div style="background: #22567C; color: #FFFFFF; padding: 18px 24px; font-size: 20px; font-weight: 400;">
#             Sample 2 of 6
#         </div>
#
#         <div style="background: #FFFFFF; border-left: 6px solid #1795D4; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #22567C; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Customer Ticket
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">Ticket #7823<br>Customer: rachel.foster@meridian.co<br>Plan: Enterprise<br>Issue: Our weekly report export is timing out. It used to complete in about 2 minutes but now it just spins for 10+ minutes then fails. We can still pull smaller date ranges manually but the full export doesn&#x27;t work.</div>
#         </div>
#
#         <div style="background: #F5F5F5; border-left: 6px solid #269C9E; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #269C9E; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Fine-Tuned Model Response (SageMaker)
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">## Internal Bug Report<br><br>Severity: P3 (non-blocking)<br><br>Owner: Data Team<br><br>Summary: Weekly report export times out, blocking manual data pull<br><br>Probable Cause: API request timeout or rate limiting may be in place, or the data source is experiencing high load<br><br>Suggested Investigation:<br>1. Check API request logs for failed requests<br>2. Review data ingestion pipeline for rate limiting or timeout checks<br>3. Run `curl -v /api/weekly_report` in a new terminal to see if it times out immediately</div>
#         </div>
#
#         <div style="background: #FFFFFF; border-left: 6px solid #212526; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #212526; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Base Model Response (Local MLX)
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">Here&#x27;s a step-by-step solution to resolve the issue with the weekly report export:<br><br>**Step 1: Check the Server Configuration**<br><br>1. Log in to the Meridian server using the admin credentials.<br>2. Navigate to the &#x27;Reports&#x27; or &#x27;Data Export&#x27; section.<br>3. Look for the &#x27;Weekly Report&#x27; or &#x27;Enterprise Report&#x27; settings.<br>4. Check if the &#x27;Export Time Limit&#x27; is set to a reasonable value (e.g., 2 minutes).<br>5. If the time limit is too low, consider increasing it to a more suitable value.<br><br>**Step 2: Check the Data Source**<br><br>1. Verify that the data source for the weekly report is correct and up-to-date.<br>2. Check if the data source is properly configured and linked to the Meridian database.<br>3. If the data source is not properly configured, consider updating or recreating it.<br><br>**Step 3: Check the Export Settings**<br><br>1. Navigate to the &#x27;Reports&#x27; or &#x27;Data Export&#x27; section.<br>2. Look for the &#x27;Export Settings&#x27; or &#x27;Export Options&#x27; section.<br>3. Check if the &#x27;Export Time Limit&#x27; is set to a reasonable value.<br>4. If the time limit is too low, consider increasing it to a more suitable value.<br><br>**Step 4: Check the Server Logs**<br><br>1. Log in to the Meridian server using the admin credentials.<br>2. Navigate to the &#x27;Server Logs&#x27; section.<br>3. Look for any error messages related to the weekly report export.<br>4. Check if there are any issues with the export process that could be causing the timeout.<br><br>**Step 5: Contact Support**<br><br>1. If none of the above steps resolve the issue, contact Meridian support for further assistance.<br>2. Provide the customer details, including the customer name, email address, and plan.<br>3. Request that the support team investigate the issue and provide a solution.<br><br>**Additional Troubleshooting Steps**<br><br>1. Check the system logs for any errors related to the weekly report export.<br>2. Verify that the report is not being blocked by any security policies or firewalls.<br>3. Check if the report is being exported to a different location or database than expected.<br><br>By following these steps, you should be able to identify and resolve the issue with the weekly report export.</div>
#         </div>
#
#         <details style="background: #F5F5F5; border-left: 6px solid #F07C00; padding: 18px 22px;">
#             <summary style="font-weight: 500; color: #22567C; font-size: 13px; text-transform: uppercase; letter-spacing: 1px; cursor: pointer; border-radius: 4px; padding: 4px 0;">
#                 Expected Response (Ground Truth) — click to expand
#             </summary>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; margin-top: 14px; color: #212526; line-height: 1.6;">## Internal Bug Report<br><br>Severity: P2 (service degraded)<br><br>Owner: Data Platform Team<br><br>Summary: Weekly report export timing out after 10+ minutes<br><br>Probable Cause: REPORTS_WH may be undersized for the growing dataset, or a recent schema change increased query complexity.<br><br>Suggested Investigation:<br>1. Check Snowflake query history for timeout errors on export queries against `REPORTS_WH`<br>2. Run `/scripts/snowflake/warehouse_utilization.sh REPORTS_WH` to assess capacity vs demand<br>3. Review recent changes to report generation DAGs in Astronomer UI</div>
#         </details>
#     </div>
#     <link href="https://fonts.googleapis.com/css2?family=Lexend:wght@300;400;500&display=swap" rel="stylesheet">
#     <div style="font-family: 'Lexend', sans-serif; margin: 24px 0; overflow: hidden; box-shadow: 0 2px 8px rgba(33,37,38,0.1); border: 1px solid #E0E0E0;">
#         <div style="background: #22567C; color: #FFFFFF; padding: 18px 24px; font-size: 20px; font-weight: 400;">
#             Sample 3 of 6
#         </div>
#
#         <div style="background: #FFFFFF; border-left: 6px solid #1795D4; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #22567C; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Customer Ticket
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">Ticket #9012<br>Customer: nina.petrov@designlab.co<br>Plan: Starter<br>Issue: Small thing - the chart colours on my dashboard changed recently? They used to be blue/green and now they&#x27;re purple/orange. Just wondering if that was intentional.</div>
#         </div>
#
#         <div style="background: #F5F5F5; border-left: 6px solid #269C9E; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #269C9E; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Fine-Tuned Model Response (SageMaker)
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">## Internal Bug Report<br><br>Severity: P3 (non-blocking)<br><br>Owner: Data Team<br><br>Summary: Dashboard color palette change<br><br>Probable Cause: Data team may have updated the color palette in a recent release without notifying the dashboard team.<br><br>Suggested Investigation:<br>1. Check the data team&#x27;s release notes for any changes to the dashboard color palette.<br>2. Review the dashboard&#x27;s color palette in the UI to see if the change was intentional.<br>3. If the change was intentional, verify that the data team was notified and that the change was documented in the release notes.</div>
#         </div>
#
#         <div style="background: #FFFFFF; border-left: 6px solid #212526; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #212526; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Base Model Response (Local MLX)
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">Hello Nina,<br><br>Thank you for reaching out to us about the issue with the chart colors on your dashboard. I&#x27;m happy to help you resolve the problem.<br><br>The change in chart colors from blue/green to purple/orange is indeed an intentional change. Our team made this adjustment to improve the visual appeal and consistency of our dashboard.<br><br>The new color scheme is designed to be more vibrant and attention-grabbing, which is perfect for a design lab. The purple/orange color combination is also more energetic and engaging, which can help to stimulate creativity and inspire innovation.<br><br>If you&#x27;re not satisfied with the new color scheme, we can discuss alternative options or even revert to the original blue/green color scheme. However, I would like to ask a few questions to better understand your preferences:<br><br>1. Are you happy with the new color scheme overall?<br>2. Are there any specific design elements or features that you&#x27;d like to see changed or restored to the original blue/green color scheme?<br>3. Are there any other design elements or features that you&#x27;d like to see added or removed from the dashboard?<br><br>Please let me know your thoughts, and I&#x27;ll do my best to accommodate your requests or provide alternative solutions.</div>
#         </div>
#
#         <details style="background: #F5F5F5; border-left: 6px solid #F07C00; padding: 18px 22px;">
#             <summary style="font-weight: 500; color: #22567C; font-size: 13px; text-transform: uppercase; letter-spacing: 1px; cursor: pointer; border-radius: 4px; padding: 4px 0;">
#                 Expected Response (Ground Truth) — click to expand
#             </summary>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; margin-top: 14px; color: #212526; line-height: 1.6;">## Internal Bug Report<br><br>Severity: P3 (non-blocking)<br><br>Owner: Data Platform Team<br><br>Summary: Dashboard chart colour scheme changed unexpectedly<br><br>Probable Cause: Recent Sigma template or theme update may have altered default colour palettes for charts.<br><br>Suggested Investigation:<br>1. Review recent Sigma template deployments for colour scheme changes<br>2. Check if customer&#x27;s dashboard is using default theme vs custom palette<br>3. Confirm whether this was an intentional design update and update release notes if so</div>
#         </details>
#     </div>
#     <link href="https://fonts.googleapis.com/css2?family=Lexend:wght@300;400;500&display=swap" rel="stylesheet">
#     <div style="font-family: 'Lexend', sans-serif; margin: 24px 0; overflow: hidden; box-shadow: 0 2px 8px rgba(33,37,38,0.1); border: 1px solid #E0E0E0;">
#         <div style="background: #22567C; color: #FFFFFF; padding: 18px 24px; font-size: 20px; font-weight: 400;">
#             Sample 4 of 6
#         </div>
#
#         <div style="background: #FFFFFF; border-left: 6px solid #1795D4; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #22567C; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Customer Ticket
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">Ticket #7812<br>Customer: michael.oconnor@finserve.co.uk<br>Plan: Enterprise<br>Issue: URGENT - Our entire sales floor (50+ people) cannot log in. Getting 401 errors on every attempt. We&#x27;re losing deals right now. Need this fixed immediately.</div>
#         </div>
#
#         <div style="background: #F5F5F5; border-left: 6px solid #269C9E; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #269C9E; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Fine-Tuned Model Response (SageMaker)
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">## Internal Bug Report<br><br>Severity: P1 (business-critical)<br><br>Owner: IT Operations<br><br>Summary: Sales team unable to log in due to 401 errors<br><br>Probable Cause: Authentication server may be experiencing high load or token refresh issues, causing rate limiting and 401 errors.<br><br>Suggested Investigation:<br>1. Check authentication server logs for rate limiting errors<br>2. Verify token refresh is working as expected<br>3. Run `curl -v /auth/refresh_token` in IT Ops to check for errors</div>
#         </div>
#
#         <div style="background: #FFFFFF; border-left: 6px solid #212526; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #212526; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Base Model Response (Local MLX)
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">**URGENT - Sales Floor Login Issue**<br><br>**Customer Information:**<br><br>- Name: Michael O&#x27;Connor<br>- Email: michael.oconnor@finserve.co.uk<br>- Plan: Enterprise<br><br>**Issue Description:**<br><br>The entire sales floor of 50+ people is experiencing login issues, resulting in 401 errors on every attempt. This is causing significant delays in deal closure, which is critical to the business&#x27;s success.<br><br>**Current Status:**<br><br>- Number of affected users: 50+<br>- Number of affected users: 50+<br>- Current error message: 401 errors<br><br>**Request:**<br><br>We require immediate assistance to resolve this issue. The following steps should be taken:<br><br>1. **Immediate Login Restriction:** Restrict login access to the sales floor for the next 24 hours to prevent further disruptions.<br>2. **Error Analysis:** Conduct a thorough analysis of the login process to identify the root cause of the 401 errors.<br>3. **Technical Support:** Provide technical support to the sales floor to resolve the issue and ensure seamless login functionality.<br>4. **Escalation:** Escalate the issue to our technical team for further investigation and resolution.<br><br>**Timeline:**<br><br>- Immediate action: 30 minutes<br>- Analysis and resolution: 2 hours<br>- Escalation and support: 2 hours<br><br>**Next Steps:**<br><br>- The sales floor will be restricted from login access for the next 24 hours.<br>- Technical support will be provided to resolve the issue.<br>- The sales floor will be monitored for any further disruptions.<br><br>**Contact Information:**<br><br>- Michael O&#x27;Connor: michael.oconnor@finserve.co.uk<br>- Technical Support: [support@finserve.co.uk](mailto:support@finserve.co.uk)<br><br>**Resolution Status:**<br><br>The issue is being investigated and resolved as per the above steps. We will provide an update on the resolution status once it is complete.</div>
#         </div>
#
#         <details style="background: #F5F5F5; border-left: 6px solid #F07C00; padding: 18px 22px;">
#             <summary style="font-weight: 500; color: #22567C; font-size: 13px; text-transform: uppercase; letter-spacing: 1px; cursor: pointer; border-radius: 4px; padding: 4px 0;">
#                 Expected Response (Ground Truth) — click to expand
#             </summary>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; margin-top: 14px; color: #212526; line-height: 1.6;">## Internal Bug Report<br><br>Severity: P1 (business-critical)<br><br>Owner: Auth Team<br><br>Summary: Organisation-wide login failure with 401 errors affecting 50+ users<br><br>Probable Cause: Auth-service may be returning invalid tokens, or API gateway rejecting valid credentials due to misconfigured authentication middleware.<br><br>Suggested Investigation:<br>1. Check `auth-service` pods in ArgoCD for restarts or failed deployments<br>2. Run `/scripts/auth/token_debug.sh finserve_org_id` to trace token generation flow<br>3. Review Datadog APM for 401 spike patterns on `/auth/login` endpoint</div>
#         </details>
#     </div>
#     <link href="https://fonts.googleapis.com/css2?family=Lexend:wght@300;400;500&display=swap" rel="stylesheet">
#     <div style="font-family: 'Lexend', sans-serif; margin: 24px 0; overflow: hidden; box-shadow: 0 2px 8px rgba(33,37,38,0.1); border: 1px solid #E0E0E0;">
#         <div style="background: #22567C; color: #FFFFFF; padding: 18px 24px; font-size: 20px; font-weight: 400;">
#             Sample 5 of 6
#         </div>
#
#         <div style="background: #FFFFFF; border-left: 6px solid #1795D4; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #22567C; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Customer Ticket
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">Ticket #3847<br>Customer: rachel.green@designstudio.co<br>Plan: Personal<br>Issue: My sessions keep dropping randomly throughout the day. Sometimes I can work for 2 hours, sometimes only 20 minutes before getting kicked out. Started about 3 days ago. Getting old tbh.</div>
#         </div>
#
#         <div style="background: #F5F5F5; border-left: 6px solid #269C9E; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #269C9E; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Fine-Tuned Model Response (SageMaker)
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">## Internal Bug Report<br><br>Severity: P3 (non-critical)<br><br>Owner: Data Engineering<br><br>Summary: Random session timeouts in personal plan<br><br>Probable Cause: Session timeout may be triggered by increasing CPU load or idle timeout threshold being set too low, but also possible due to rate limiting or session revocation logic not catching session timeouts.<br><br>Suggested Investigation:<br>1. Check Redis session timeout settings and rate limiting for personal plan users<br>2. Review session revocation logic and timeout threshold for personal plan users<br>3. Check for recent changes to session timeout settings or rate limiting in the data pipeline</div>
#         </div>
#
#         <div style="background: #FFFFFF; border-left: 6px solid #212526; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #212526; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Base Model Response (Local MLX)
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">I&#x27;m here to help you with your issue. Here are a few potential solutions to help you minimize the random session drops:<br><br>1. **Check your internet connection**: Ensure your internet connection is stable and fast enough to support your work sessions. A slow or unstable connection can cause your sessions to drop randomly.<br><br>2. **Adjust your session duration**: Consider setting a specific session duration for each session. This can help you stay focused and avoid getting kicked out too quickly.<br><br>3. **Use a timer or a countdown**: Set a timer or a countdown for each session to help you stay on track and avoid getting distracted.<br><br>4. **Prioritize your tasks**: Make a to-do list and prioritize your tasks. Focus on the most important tasks first, and then move on to less important ones.<br><br>5. **Take breaks**: Take regular breaks to recharge and refocus. This can help you stay productive and avoid getting distracted.<br><br>6. **Consider a productivity app**: There are many productivity apps available that can help you stay focused and on track. Some popular options include Freedom, StayFocused, and Focus@Will.<br><br>7. **Adjust your workspace**: Make sure your workspace is comfortable and conducive to productivity. Adjust the lighting, temperature, and noise levels to create an environment that works for you.<br><br>8. **Use a tool to track your sessions**: Consider using a tool like RescueTime or Toggl to track your sessions and identify patterns. This can help you identify areas where you can improve your productivity.<br><br>9. **Communicate with your team**: If you&#x27;re working with a team, communicate with them about your issues. They may be able to offer suggestions or provide support to help you stay focused.<br><br>10. **Consider a productivity coach**: If you&#x27;re struggling to stay focused and productive, consider hiring a productivity coach. They can help you identify areas where you can improve and provide personalized guidance to help you achieve your goals.<br><br>I hope these suggestions help you minimize the random session drops and stay productive. If you have any further questions or concerns, feel free to ask.</div>
#         </div>
#
#         <details style="background: #F5F5F5; border-left: 6px solid #F07C00; padding: 18px 22px;">
#             <summary style="font-weight: 500; color: #22567C; font-size: 13px; text-transform: uppercase; letter-spacing: 1px; cursor: pointer; border-radius: 4px; padding: 4px 0;">
#                 Expected Response (Ground Truth) — click to expand
#             </summary>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; margin-top: 14px; color: #212526; line-height: 1.6;">## Internal Bug Report<br><br>Severity: P2 (service degraded)<br><br>Owner: Auth Team<br><br>Summary: Intermittent session drops with inconsistent timing patterns<br><br>Probable Cause: Token refresh may be failing sporadically due to race condition in refresh logic, or Redis session TTL is being set inconsistently.<br><br>Suggested Investigation:<br>1. Check Datadog APM for intermittent failures on `/auth/refresh` endpoint over past 3 days<br>2. Run `/scripts/auth/session_ttl_check.sh` to verify TTL consistency across sessions<br>3. Review Kibana logs for user ID to identify session termination triggers</div>
#         </details>
#     </div>
#     <link href="https://fonts.googleapis.com/css2?family=Lexend:wght@300;400;500&display=swap" rel="stylesheet">
#     <div style="font-family: 'Lexend', sans-serif; margin: 24px 0; overflow: hidden; box-shadow: 0 2px 8px rgba(33,37,38,0.1); border: 1px solid #E0E0E0;">
#         <div style="background: #22567C; color: #FFFFFF; padding: 18px 24px; font-size: 20px; font-weight: 400;">
#             Sample 6 of 6
#         </div>
#
#         <div style="background: #FFFFFF; border-left: 6px solid #1795D4; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #22567C; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Customer Ticket
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">Ticket #2341<br>Customer: amy.collins@blogger.me<br>Plan: Starter<br>Issue: Small thing - the login page shows &quot;Login&quot; but the button says &quot;Sign In&quot;. Bit inconsistent. Not a big deal just noticed it.</div>
#         </div>
#
#         <div style="background: #F5F5F5; border-left: 6px solid #269C9E; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #269C9E; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Fine-Tuned Model Response (SageMaker)
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">## Internal Bug Report<br><br>Severity: P3 (non-blocking)<br><br>Owner: Product Team<br><br>Summary: Login page inconsistent between &quot;Login&quot; and &quot;Sign In&quot; buttons<br><br>Probable Cause: Possibly a typo in the login page&#x27;s HTML or CSS, or a layout issue that&#x27;s not immediately apparent.<br><br>Suggested Investigation:<br>1. Check the login page&#x27;s HTML and CSS for any typos or layout issues.<br>2. Verify that the &quot;Sign In&quot; button is being generated correctly by the login form&#x27;s JavaScript.<br>3. If the issue is with the frontend, check the browser&#x27;s developer tools for any layout or styling errors.</div>
#         </div>
#
#         <div style="background: #FFFFFF; border-left: 6px solid #212526; padding: 18px 22px;">
#             <div style="font-weight: 500; color: #212526; margin-bottom: 12px; font-size: 13px; text-transform: uppercase; letter-spacing: 1px;">
#                 Base Model Response (Local MLX)
#             </div>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; color: #212526; line-height: 1.6;">Here&#x27;s a suggested solution:<br><br>**Option 1: Simple Text Change**<br><br>Replace the button text with &quot;Sign In&quot; in the HTML code:<br><br>```html<br>&lt;button type=&quot;submit&quot;&gt;Sign In&lt;/button&gt;<br>```<br><br>This change will resolve the inconsistency and make the login page more user-friendly.<br><br>**Option 2: CSS Solution**<br><br>Add a CSS rule to change the button text:<br><br>```css<br>button[type=&quot;submit&quot;] {<br>  text-align: center;<br>  padding: 10px 20px;<br>  font-size: 16px;<br>  font-weight: bold;<br>  background-color: #4CAF50;<br>  color: #fff;<br>  border: none;<br>  border-radius: 5px;<br>  cursor: pointer;<br>}<br>```<br><br>This will center the text, increase the font size, and add a background color, making the button look more appealing.<br><br>**Option 3: JavaScript Solution**<br><br>Add a JavaScript function to change the button text:<br><br>```javascript<br>document.querySelector(&#x27;button[type=&quot;submit&quot;]&#x27;).textContent = &#x27;Sign In&#x27;;<br>```<br><br>This will change the button text to &quot;Sign In&quot; immediately when the page loads.<br><br>Choose the solution that best fits your needs, and test it to ensure it works as expected.</div>
#         </div>
#
#         <details style="background: #F5F5F5; border-left: 6px solid #F07C00; padding: 18px 22px;">
#             <summary style="font-weight: 500; color: #22567C; font-size: 13px; text-transform: uppercase; letter-spacing: 1px; cursor: pointer; border-radius: 4px; padding: 4px 0;">
#                 Expected Response (Ground Truth) — click to expand
#             </summary>
#             <div style="font-family: 'Lexend', sans-serif; font-weight: 300; font-size: 13px; margin-top: 14px; color: #212526; line-height: 1.6;">## Internal Bug Report<br><br>Severity: P3 (non-blocking)<br><br>Owner: Auth Team<br><br>Summary: Inconsistent terminology between page title (&quot;Login&quot;) and button text (&quot;Sign In&quot;)<br><br>Probable Cause: UI copy inconsistency in auth-service frontend templates, likely introduced during localisation updates.<br><br>Suggested Investigation:<br>1. Review auth-service login page templates for terminology consistency<br>2. Check localisation files for &quot;login&quot; vs &quot;sign in&quot; usage across all strings<br>3. Create ticket for UX team to establish standard terminology guidelines</div>
#         </details>
#     </div>
